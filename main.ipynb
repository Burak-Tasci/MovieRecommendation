# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os
import glob

plt.rcParams["figure.figsize"] = (20,10)

# %%
files = glob.glob(".\\data\\*.csv")
files
# Out:
# ['.\\data\\IMDb movies.csv',
#  '.\\data\\IMDb names.csv',
#  '.\\data\\IMDb ratings.csv',
#  '.\\data\\IMDb title_principals.csv']

# %%
IMDB_movies = pd.read_csv(files[0], low_memory=False)
IMDB_movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
IMDB_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
IMDB_movies.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
condition = (IMDB_movies.loc[:,["title"]].values == IMDB_movies.loc[:,["original_title"]].values)
condition
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
# True values count
condition.sum()
# Out:
# 62483

# %%
# All values count
len(condition)
# Out:
# 85855

# %%
IMDB_movies[condition == False]
# Out:
#       imdb_title_id                                          title  \
# 12        tt0003014                       Il calvario di una madre
# 17        tt0003167                                 Amore di madre
# 18        tt0003419                           Lo studente di Praga
# 38        tt0004681                         La madonnina del porto
# 47        tt0004972                         Nascita di una nazione
# ...             ...                                            ...
# 85790     tt9828918                                     #IoSonoQui
# 85805     tt9850064                            Children of the Sea
# 85807     tt9855978          Dreambuilders - La fabbrica dei sogni
# 85811     tt9860728  Falling Inn Love - Ristrutturazione con amore
# 85842     tt9900060          Lupin III: La menzogna di Fujiko Mine
#
#                             original_title  year date_published  \
# 12                           Ingeborg Holm  1913     1915-10-18
# ...

# %%
condition = IMDB_movies.isna().sum() > 1000
condition
# Out:
# imdb_title_id            False
# title                    False
# original_title           False
# year                     False
# date_published           False
# genre                    False
# duration                 False
# country                  False
# language                 False
# director                 False
# writer                    True
# production_company        True
# actors                   False
# description               True
# avg_vote                 False
# votes                    False
# budget                    True
# usa_gross_income          True
# worlwide_gross_income     True
# metascore                 True
# reviews_from_users        True
# reviews_from_critics      True
# dtype: bool

# %%
IMDB_movies.isna().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     64
# language                   833
# director                    87
# writer                    1572
# production_company        4455
# actors                      69
# description               2115
# avg_vote                     0
# votes                        0
# budget                   62145
# usa_gross_income         70529
# worlwide_gross_income    54839
# metascore                72550
# reviews_from_users        7597
# reviews_from_critics     11797
# dtype: int64

# %%
columns_to_drop = ["title", "budget", "usa_gross_income", "worlwide_gross_income", "metascore", "reviews_from_users", "reviews_from_critics", "description", "production_company"]

# %%
for i in columns_to_drop:
    del IMDB_movies[i]

# %%
IMDB_movies.head()
# Out:
#   imdb_title_id               original_title  year date_published  \
# 0     tt0000009                   Miss Jerry  1894     1894-10-09
# 1     tt0000574  The Story of the Kelly Gang  1906     1906-12-26
# 2     tt0001892               Den sorte drøm  1911     1911-08-19
# 3     tt0002101                    Cleopatra  1912     1912-11-13
# 4     tt0002130                    L'Inferno  1911     1911-03-06
#
#                        genre  duration           country language  \
# 0                    Romance        45               USA     None
# 1    Biography, Crime, Drama        70         Australia     None
# 2                      Drama        53  Germany, Denmark      NaN
# 3             Drama, History       100               USA  English
# 4  Adventure, Drama, Fantasy        68             Italy  Italian
#
#                               director                                 writer  \
# 0                      Alexander Black                        Alexander Black
# ...

# %%
IMDB_movies.isna().sum()
# Out:
# imdb_title_id        0
# original_title       0
# year                 0
# date_published       0
# genre                0
# duration             0
# country             64
# language           833
# director            87
# writer            1572
# actors              69
# avg_vote             0
# votes                0
# dtype: int64

# %%
IMDB_movies.head()
# Out:
#   imdb_title_id               original_title  year date_published  \
# 0     tt0000009                   Miss Jerry  1894     1894-10-09
# 1     tt0000574  The Story of the Kelly Gang  1906     1906-12-26
# 2     tt0001892               Den sorte drøm  1911     1911-08-19
# 3     tt0002101                    Cleopatra  1912     1912-11-13
# 4     tt0002130                    L'Inferno  1911     1911-03-06
#
#                        genre  duration           country language  \
# 0                    Romance        45               USA     None
# 1    Biography, Crime, Drama        70         Australia     None
# 2                      Drama        53  Germany, Denmark      NaN
# 3             Drama, History       100               USA  English
# 4  Adventure, Drama, Fantasy        68             Italy  Italian
#
#                               director                                 writer  \
# 0                      Alexander Black                        Alexander Black
# ...

# %%
a = IMDB_movies.loc[:,["country", "language"]].replace(None,None)
a
# Out:
#                 country       language
# 0                   USA           None
# 1             Australia           None
# 2      Germany, Denmark           None
# 3                   USA        English
# 4                 Italy        Italian
# ...                 ...            ...
# 85850   France, Belgium         French
# 85851       Netherlands  German, Dutch
# 85852             India      Malayalam
# 85853            Turkey        Turkish
# 85854             Spain        Catalan
#
# [85855 rows x 2 columns]

# %%
country_condition = a.loc[:,["country"]] == "USA"
a[country_condition.values.ravel()].language = "English"
a
# Out:
# C:\Users\ABRA\.conda\envs\tensor_gpu\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                 country       language
# 0                   USA           None
# 1             Australia           None
# 2      Germany, Denmark           None
# 3                   USA        English
# 4                 Italy        Italian
# ...                 ...            ...
# 85850   France, Belgium         French
# 85851       Netherlands  German, Dutch
# 85852             India      Malayalam
# 85853            Turkey        Turkish
# 85854             Spain        Catalan
#
# [85855 rows x 2 columns]

# %%
a[country_condition]
# Out:
#        country language
# 0      English      NaN
# 1          NaN      NaN
# 2          NaN      NaN
# 3      English      NaN
# 4          NaN      NaN
# ...        ...      ...
# 85850      NaN      NaN
# 85851      NaN      NaN
# 85852      NaN      NaN
# 85853      NaN      NaN
# 85854      NaN      NaN
#
# [85855 rows x 2 columns]
